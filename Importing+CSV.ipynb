# %%
print("Hello World")
# Out:
# Hello World

# %%
import pandas as pd

# %%
fb = pd.DataFrame.from_csv('../data/facebook.csv')

# %%
ms = pd.DataFrame.from_csv('../data/microsoft.csv')

# %%
print(ms.iloc[0,0])
# Out:
# 46.73

# %%
print(ms.iloc[0,1])
# Out:
# 47.439999

# %%
print(fb.iloc[0,1])
# Out:
# 20.51

# %%
fb.head()
# Out:
#                  Open       High        Low      Close  Adj Close   Volume
# Date
# 2014-12-31  20.400000  20.510000  19.990000  20.049999  19.459270  4157500
# 2015-01-02  20.129999  20.280001  19.809999  20.129999  19.536913  2842000
# 2015-01-05  20.129999  20.190001  19.700001  19.790001  19.206934  4948800
# 2015-01-06  19.820000  19.840000  19.170000  19.190001  18.624611  4944100
# 2015-01-07  19.330000  19.500000  19.080000  19.139999  18.576082  8045200

# %%
ms.head()
# Out:
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2014-12-31  46.730000  47.439999  46.450001  46.450001  42.848763  21552500
# 2015-01-02  46.660000  47.419998  46.540001  46.759998  43.134731  27913900
# 2015-01-05  46.369999  46.730000  46.250000  46.330002  42.738068  39673900
# 2015-01-06  46.380001  46.750000  45.540001  45.650002  42.110783  36447900
# 2015-01-07  45.980000  46.459999  45.490002  46.230000  42.645817  29114100

# %%
fb.head
# Out:
# <bound method NDFrame.head of                   Open        High         Low       Close   Adj Close  \
# Date
# 2014-12-31   20.400000   20.510000   19.990000   20.049999   19.459270
# 2015-01-02   20.129999   20.280001   19.809999   20.129999   19.536913
# 2015-01-05   20.129999   20.190001   19.700001   19.790001   19.206934
# 2015-01-06   19.820000   19.840000   19.170000   19.190001   18.624611
# 2015-01-07   19.330000   19.500000   19.080000   19.139999   18.576082
# 2015-01-08   19.360001   19.980000   19.350000   19.860001   19.274870
# 2015-01-09   19.930000   20.090000   19.660000   19.940001   19.352512
# 2015-01-12   19.990000   20.000000   19.510000   19.690001   19.109879
# 2015-01-13   19.840000   20.240000   19.520000   19.660000   19.080761
# 2015-01-14   19.450001   19.799999   19.400000   19.740000   19.158401
# 2015-01-15   19.879999   20.000000   19.590000   19.600000   19.022530
# 2015-01-16   19.570000   19.980000   19.510000   19.959999   19.371923
# ...

# %%
fb.index
# Out:
# DatetimeIndex(['2014-12-31', '2015-01-02', '2015-01-05', '2015-01-06',
#                '2015-01-07', '2015-01-08', '2015-01-09', '2015-01-12',
#                '2015-01-13', '2015-01-14',
#                ...
#                '2018-01-23', '2018-01-24', '2018-01-25', '2018-01-26',
#                '2018-01-29', '2018-01-30', '2018-01-31', '2018-02-01',
#                '2018-02-02', '2018-02-05'],
#               dtype='datetime64[ns]', name='Date', length=780, freq=None)

# %%
fb.index[0]
# Out:
# Timestamp('2014-12-31 00:00:00')

# %%
fb.index[-1]
# Out:
# Timestamp('2018-02-05 00:00:00')

# %%
fb.shape
# Out:
# (780, 6)

# %%
fb.tail()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2018-01-30  241.110001  246.419998  238.410004  242.720001  242.720001
# 2018-01-31  245.770004  249.270004  244.449997  245.800003  245.800003
# 2018-02-01  238.520004  246.899994  238.059998  240.500000  240.500000
# 2018-02-02  237.000000  237.970001  231.169998  233.520004  233.520004
# 2018-02-05  227.000000  233.229996  205.000000  213.699997  213.699997
#
#               Volume
# Date
# 2018-01-30  14270800
# 2018-01-31  11964400
# 2018-02-01  12980600
# 2018-02-02  17961600
# 2018-02-05  28869000

# %%
fb.describe()
# Out:
#              Open        High         Low       Close   Adj Close  \
# count  780.000000  780.000000  780.000000  780.000000  780.000000
# mean    80.212705   81.285654   79.022397   80.264897   79.914215
# std     64.226121   65.048907   63.190963   64.198375   64.327846
# min     19.250000   19.500000   18.940001   19.139999   18.576082
# 25%     25.525000   26.085000   24.845000   25.475000   25.134513
# 50%     53.379999   54.034999   52.930000   53.420000   53.035403
# 75%    113.322502  115.779999  110.297499  113.702501  113.261238
# max    245.770004  249.270004  244.449997  246.850006  246.850006
#
#              Volume
# count  7.800000e+02
# mean   1.204453e+07
# std    8.221848e+06
# min    1.311200e+06
# 25%    7.215200e+06
# 50%    9.728700e+06
# 75%    1.408885e+07
# max    9.232320e+07

# %%
fb.loc['2015-01-02','Close']
# Out:
# 20.129999000000002

# %%
fb.iloc[1,3]
# Out:
# 20.129999000000002

# %%
fb.loc['2015-01-01':'2015-12-31', 'Close']
# Out:
# Date
# 2015-01-02    20.129999
# 2015-01-05    19.790001
# 2015-01-06    19.190001
# 2015-01-07    19.139999
# 2015-01-08    19.860001
# 2015-01-09    19.940001
# 2015-01-12    19.690001
# 2015-01-13    19.660000
# 2015-01-14    19.740000
# 2015-01-15    19.600000
# 2015-01-16    19.959999
# 2015-01-20    20.020000
# 2015-01-21    20.299999
# 2015-01-22    20.650000
# 2015-01-23    20.709999
# 2015-01-26    20.620001
# 2015-01-27    19.629999
# 2015-01-28    19.309999
# 2015-01-29    19.780001
# 2015-01-30    19.200001
# 2015-02-02    19.620001
# 2015-02-03    20.110001
# 2015-02-04    20.160000
# 2015-02-05    20.490000
# 2015-02-06    20.400000
# 2015-02-09    20.379999
# 2015-02-10    20.950001
# 2015-02-11    20.809999
# 2015-02-12    22.299999
# 2015-02-13    22.309999
#                 ...
# 2015-11-18    31.030001
# 2015-11-19    31.120001
# 2015-11-20    31.389999
# 2015-11-23    30.920000
# 2015-11-24    31.170000
# 2015-11-25    31.129999
# 2015-11-27    31.389999
# ...

# %%
fb.iloc[624,:]
# Out:
# Open         1.586800e+02
# High         1.593200e+02
# Low          1.532200e+02
# Close        1.538300e+02
# Adj Close    1.535880e+02
# Volume       2.721470e+07
# Name: 2017-06-23 00:00:00, dtype: float64

# %%
fb.iloc[624:,:]
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2017-06-23  158.679993  159.320007  153.220001  153.830002  153.587982
# 2017-06-26  155.160004  156.600006  148.330002  152.149994  151.910614
# 2017-06-27  151.440002  151.789993  146.350006  146.580002  146.349380
# 2017-06-28  149.320007  151.940002  145.750000  151.750000  151.511246
# 2017-06-29  150.600006  150.720001  144.080002  146.679993  146.449219
# 2017-06-30  147.380005  147.929993  143.500000  144.559998  144.332550
# 2017-07-03  145.050003  145.649994  138.580002  139.330002  139.110794
# 2017-07-05  141.899994  144.220001  141.130005  143.050003  142.824936
# 2017-07-06  141.869995  145.380005  139.759995  143.479996  143.254257
# 2017-07-07  145.779999  147.500000  144.850006  146.759995  146.529099
# 2017-07-10  149.740005  154.000000  148.679993  153.699997  153.458176
# 2017-07-11  153.850006  156.190002  152.149994  155.880005  155.634766
# ...

# %%
fb.loc['2017-01-01':'2017-12-31', 'Close'].plot(kind='line') # 2015

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
fb.loc['2017-01-01':'2017-12-31', 'Close'].plot()# 2017
fb.loc['2018-01-01':'2018-12-31', 'Close'].plot()# 2018
